# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from cbf import generate_pattern_data, generate_bell, generate_cylinder, generate_funnel

# %%
length = 1000
avg_amplitude = 10
avg_pattern_length = 40
generators = [generate_bell, generate_cylinder, generate_funnel]
data = generate_pattern_data(length, avg_pattern_length, avg_amplitude, default_variance = 1, 
                             variance_pattern_length = 30, generators = generators, include_negatives=True)
plt.plot(np.arange(length), data)
plt.show()

# %%
length = 1000
avg_amplitude = 10
avg_pattern_length = 40
generators = [generate_bell, generate_cylinder, generate_funnel]
data = generate_pattern_data(length, avg_pattern_length, avg_amplitude, default_variance = 0.00001, 
                             variance_pattern_length = 30, generators = generators, include_negatives=True)
plt.plot(np.arange(length), data)
plt.show()

# %%
length = 1000
avg_amplitude = 10
avg_pattern_length = 40
generators = [generate_bell, generate_cylinder, generate_funnel]
data = generate_pattern_data(length, avg_pattern_length, avg_amplitude, default_variance = 1, 
                             variance_pattern_length = 30, generators = generators, include_negatives=False)
plt.plot(np.arange(length), data)
plt.show()

# %%
length = 1000
avg_amplitude = 10
avg_pattern_length = 40
generators = [generate_bell, generate_funnel]
data = generate_pattern_data(length, avg_pattern_length, avg_amplitude, default_variance = 1, 
                             variance_pattern_length = 30, generators = generators, include_negatives=True)
plt.plot(np.arange(length), data)
plt.show()
